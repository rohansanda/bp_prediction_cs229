# %% [markdown]
# Rohan Sanda 2023

# %% [markdown]
# ### This is what I used to plot grid search results and model outputs ###

# %%
import pickle
import torch
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## GridSearch Logs ##

# %%
with open('/Users/rohansanda/Desktop/cs229_proj/6_7_losses/ann/mse_losses_ann75.pickle', 'rb') as file:
    losses_cnn = pickle.load(file)

# %%
with open('/Users/rohansanda/Desktop/cs229_proj/6_7_losses/resnet/hyper_parameter_tuning.pickle', 'rb') as file:
    hyp_cnn = pickle.load(file)

# %%
hyp_cnn
# Out:
# ["Epoch: 0, Hyper parameters: (<class 'torch.optim.adam.Adam'>, 0.001, 0.01), Train Loss: 448.4927733712333, Val Loss: 390.7607108470073, Train SBP MSE: 310.47469941278484, Val SBP MSE: 273.39717170695354, Train SBP MAE: 13.533002185465536, Val SBP MAE: 12.900113423701695, Train SBP R2: 0.15266521499714047, Val SBP R2: 0.25467290959845523, Train DBP MSE: 107.5443934111887, Val DBP MSE: 95.97032713384904, Train DBP MAE: 8.107762809000992, Val DBP MAE: 7.7348762787410195, Train DBP R2: 0.1467901740859845, Val DBP R2: 0.2392209753771375",
# ...

# %% [markdown]
# ## Loss Curves ##

# %% [markdown]
# ### ANN Analysis ###

# %%
with open('/Users/rohansanda/Desktop/cs229_proj/6_7_losses/ann/final/losses.pickle', 'rb') as file:
    losses_ann = pickle.load(file)

# %%
with open('/Users/rohansanda/Desktop/cs229_proj/6_7_losses/ann/final/mse_losses.pickle', 'rb') as file:
    mse_ann = pickle.load(file)

# %%
with open('/Users/rohansanda/Desktop/cs229_proj/6_7_losses/ann/final/mae_losses.pickle', 'rb') as file:
    mae_ann = pickle.load(file)

# %%
with open('/Users/rohansanda/Desktop/cs229_proj/6_7_losses/ann/final/mae_losses.pickle', 'rb') as file:
    mae_ann = pickle.load(file)

# %%
with open('/Users/rohansanda/Desktop/cs229_proj/6_7_losses/ann/final/r2_scores.pickle', 'rb') as file:
    r2_ann = pickle.load(file)

# %%
def extract(arr):
    sys = []
    dia = []
    for i in range(len(arr)):
        sys.append(arr[i][0])
        dia.append(arr[i][1])
    return sys, dia

# %%
mse_train = mse_ann['train_mse'][1:]
mse_val = mse_ann['val_mse'][1:]
r2_train = r2_ann['train_r2'][1:]
r2_val = r2_ann['val_r2'][1:]
# loss_train = losses_ann['train_loss'][1:]
# loss_val = losses_ann['val_loss'][1:]
mae_train = mae_ann['train_mae'][1:]
mae_val = mae_ann['val_mae'][1:]

# %%
mse_train
# Out:
# [[1617.8402600769757, 324.2362955029821],
#  [306.0039071274695, 110.20879721430953],
#  [282.14353030909814, 103.76853246621505],
#  [271.24935365705926, 100.24904418602686],
#  [264.11482105960647, 97.51248192096688],
#  [258.363064521931, 95.21997826187584],
#  [253.1298073053889, 93.35545928706557],
#  [248.74079118853814, 91.78084495478562],
#  [244.91023328577265, 90.6605161332184],
#  [241.57330972518713, 89.69220537749574],
#  [238.55680503415616, 88.76116223468074],
#  [236.11731508363567, 88.11762618312746],
#  [233.79708923433492, 87.52022641213259],
#  [231.5124274847032, 86.96974974826767],
#  [229.60639593098844, 86.46665379406707],
#  [227.95892180659283, 86.03542891417888],
#  [226.49229077119855, 85.59430518027817],
#  [224.9439458071216, 85.29979192144064],
#  [223.5934686753361, 84.93976636621252],
#  [222.31985545874588, 84.65059272020656],
#  [221.20111667429268, 84.29833241449985],
#  [220.27065320720254, 84.056302863968],
# ...

# %%
mse_val_sbp, mse_val_dbp = extract(mse_val)
mse_train_sbp, mse_train_dbp = extract(mse_train)

mae_val_sbp, mae_val_dbp = extract(mae_val)
mae_train_sbp, mae_train_dbp = extract(mae_train)

# %%
# Plot the losses
# plt.plot(mae_val_sbp, label='Validation Loss')
# plt.plot(mae_train_sbp, label='Training Loss')
# plt.xlabel('Epoch')
# plt.ylabel('Loss')
# plt.title('ANN MAE Loss')
# plt.ylim(10, 20)
# plt.legend()
# plt.show()

# plt.plot(mse_val_sbp, label='Validation Loss')
# plt.plot(mse_train_sbp, label='Training Loss')
# plt.xlabel('Epoch')
# plt.ylabel('Loss')
# plt.title('ANN MSE Loss')
# plt.ylim(150, 400)
# plt.legend()
# plt.show()

plt.plot(loss_val, label='Validation Loss')
plt.plot(loss_train, label='Training Loss')
plt.plot(mse_val_dbp, alpha=0.5, label='DBP Validation Loss')
plt.plot(mse_train_dbp, alpha=0.5, label='DBP Training Loss')
plt.plot(mse_val_sbp, alpha=0.5, label='SBP Validation Loss')
plt.plot(mse_train_sbp, alpha=0.5, label='SBP Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('ANN Combined Loss')
plt.ylim(50, 500)
plt.legend()
plt.legend(fontsize="10")
plt.grid(True)
#plt.show()

# Save the plot with higher resolution (dpi)
plt.savefig('ann_loss.png', dpi=600)

# %%
plt.grid(True)
import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage.filters import gaussian_filter1d

# Example training and validation losses
training_losses = np.array(loss_val)
validation_losses = np.array(loss_train)

# Smoothed training and validation losses
smoothed_training_losses = gaussian_filter1d(training_losses, sigma=10)
smoothed_validation_losses = gaussian_filter1d(validation_losses, sigma=10)

# Plot the smoothed loss curves
plt.plot(smoothed_training_losses, label='Smoothed Training Loss')
plt.plot(smoothed_validation_losses, label='Smoothed Validation Loss')

# Plot the actual loss values in the background
#plt.plot(training_losses, alpha=0.3, label='Training Loss (Actual)', color='gray')
#plt.plot(validation_losses, alpha=0.3, label='Validation Loss (Actual)', color='gray')

# Set plot labels and title
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Smoothed Training and Validation Loss Curves')
plt.ylim(250, 500)

# Add legend
plt.legend()

# Turn on the grid
plt.grid(True)

# Show the plot
plt.show()
# Out:
# /var/folders/b_/17z8qb5d5sj2tcsvswmzlxs40000gn/T/ipykernel_9206/2779291423.py:4: DeprecationWarning: Please use `gaussian_filter1d` from the `scipy.ndimage` namespace, the `scipy.ndimage.filters` namespace is deprecated.
#   from scipy.ndimage.filters import gaussian_filter1d

# %% [markdown]
# ### CNN Analysis ###

# %%
with open('/Users/rohansanda/Desktop/cs229_proj/6_7_losses/cnn/final/losses.pickle', 'rb') as file:
    losses_cnn = pickle.load(file)

# %%
with open('/Users/rohansanda/Desktop/cs229_proj/6_7_losses/cnn/final/mse_losses.pickle', 'rb') as file:
    mse_cnn = pickle.load(file)

# %%
with open('/Users/rohansanda/Desktop/cs229_proj/6_7_losses/cnn/final/mae_losses.pickle', 'rb') as file:
    mae_cnn = pickle.load(file)

# %%
with open('/Users/rohansanda/Desktop/cs229_proj/6_7_losses/cnn/final/r2_scores.pickle', 'rb') as file:
    r2_cnn = pickle.load(file)

# %%
mse_train = mse_cnn['train_mse'][1:]
mse_val = mse_cnn['val_mse'][1:]
loss_train = losses_cnn['train_loss'][1:]
loss_val = losses_cnn['val_loss'][1:]
mae_train = mae_cnn['train_mae'][1:]
mae_val = mae_cnn['val_mae'][1:]
r2_val = r2_cnn['val_r2'][1:]
r2_train = r2_cnn['train_r2'][1:]

# %%
r2_train
# Out:
# [[-0.3005546848370071, -0.07493118011695721],
#  [0.297695748886896, 0.2656976212032047],
#  [0.34067355851789205, 0.30854919222451715],
#  [0.37121174641117916, 0.33507358014021027],
#  [0.3938894337883526, 0.35272834340386405],
#  [0.4107160117114558, 0.36599292335550504],
#  [0.4239797427141012, 0.37546209181016743],
#  [0.433817824303354, 0.38368432881958225],
#  [0.44160451351671703, 0.3897675587235544],
#  [0.44892043588731556, 0.39684451995587644],
#  [0.4542851730337767, 0.4009131569779326],
#  [0.45946042431856027, 0.40536670282302767],
#  [0.46380082774812625, 0.4091209270681586],
#  [0.46739786602935407, 0.41299202441535554],
#  [0.4705918260633021, 0.41594311704838494],
#  [0.4731673310014378, 0.418763872338229],
#  [0.47585295161134156, 0.4213372530231748],
#  [0.47881936226682764, 0.4236721345105865],
#  [0.48073384407819153, 0.4258280842781852],
#  [0.48230400808304497, 0.428170782384347],
#  [0.4853185093392143, 0.4303144872236865],
# ...

# %%
mse_val_sbp, mse_val_dbp = extract(mse_val)
mse_train_sbp, mse_train_dbp = extract(mse_train)

mae_val_sbp, mae_val_dbp = extract(mae_val)
mae_train_sbp, mae_train_dbp = extract(mae_train)

# %%
mae_val_sbp
# Out:
# [12.52894859766279,
#  12.098070766857692,
#  11.716103088242667,
#  11.588729829324995,
#  11.320160629626683,
#  11.06341917552948,
#  11.013589441490174,
#  10.975041413961138,
#  10.831217361313955,
#  10.858387633378165,
#  10.78828496145521,
#  10.77240740598951,
#  10.597067770195007,
#  10.6793506470544,
#  10.508517857061113,
#  10.583874103409903,
#  10.595097458457946,
#  10.562155910246712,
#  10.56992569882529,
#  10.535531345122202,
#  10.4080297095435,
#  10.444458345167977,
#  10.447903583826337,
#  10.42326329473768,
#  10.533444641467502,
#  10.319911810602461,
#  10.505158743422372,
#  10.30896050177983,
#  10.320020854813713,
#  10.280631527519226,
#  10.33727048184531,
#  10.320104306493487,
#  10.48092483719417,
#  10.319056138583592,
#  10.329699570219857,
#  10.279387362153189,
#  10.34711322857993,
#  10.311014633914402,
#  10.272001853970119,
#  10.266466546440125,
#  10.160601915986197,
#  10.268950536101205,
#  10.274447373880658,
#  10.240909016554696,
# ...

# %%
# # Plot the losses
# plt.plot(mae_val_sbp, label='Validation Loss')
# plt.plot(mae_train_sbp, label='Training Loss')
# plt.xlabel('Epoch')
# plt.ylabel('Loss')
# plt.title('CNN MAE Loss')
# plt.ylim(8, 16)
# plt.legend()
# plt.show()

# plt.plot(mse_val_sbp, label='Validation Loss')
# plt.plot(mse_train_sbp, label='Training Loss')
# plt.xlabel('Epoch')
# plt.ylabel('Loss')
# plt.title('CNN MSE Loss')
# plt.ylim(100, 300)
# plt.legend()
# plt.show()

plt.plot(loss_val, label='Validation Loss')
plt.plot(loss_train, label='Training Loss')
plt.plot(mse_val_dbp, alpha=0.5, label='DBP Validation Loss')
plt.plot(mse_train_dbp, alpha=0.5, label='DBP Training Loss')
plt.plot(mse_val_sbp, alpha=0.5, label='SBP Validation Loss')
plt.plot(mse_train_sbp, alpha=0.5, label='SBP Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('CNN Combined Loss')
plt.ylim(50, 500)
plt.legend()
plt.legend(fontsize="10")
plt.grid(True)
#plt.show()

# Save the plot with higher resolution (dpi)
plt.savefig('cnn_loss.png', dpi=600)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage.filters import gaussian_filter1d

# Example training and validation losses
training_losses = s
validation_losses = np.array([1.0, 0.8, 0.7, 0.5, 0.4, 0.35, 0.3, 0.25, 0.22])

# Smoothed training and validation losses
smoothed_training_losses = gaussian_filter1d(training_losses, sigma=1)
smoothed_validation_losses = gaussian_filter1d(validation_losses, sigma=1)

# Plot the smoothed loss curves
plt.plot(smoothed_training_losses, label='Smoothed Training Loss')
plt.plot(smoothed_validation_losses, label='Smoothed Validation Loss')

# Plot the actual loss values in the background
plt.plot(training_losses, alpha=0.3, label='Training Loss (Actual)', color='gray')
plt.plot(validation_losses, alpha=0.3, label='Validation Loss (Actual)', color='gray')

# Set plot labels and title
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Smoothed Training and Validation Loss Curves')

# Add legend
plt.legend()

# Turn on the grid
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# ### ResNet Analysis ###

# %%
with open('/Users/rohansanda/Desktop/cs229_proj/6_7_losses/resnet/lr2_60_6_9/losses.pickle', 'rb') as file:
    losses_resnet = pickle.load(file)

# %%
with open('/Users/rohansanda/Desktop/cs229_proj/6_7_losses/resnet/lr2_60_6_9/mse_losses.pickle', 'rb') as file:
    mse_resnet = pickle.load(file)

# %%
with open('/Users/rohansanda/Desktop/cs229_proj/6_7_losses/resnet/lr2_60_6_9/mae_losses.pickle', 'rb') as file:
    mae_resnet = pickle.load(file)

# %%
with open('/Users/rohansanda/Desktop/cs229_proj/6_7_losses/resnet/lr2_60_6_9/r2_scores.pickle', 'rb') as file:
    r2_resnet = pickle.load(file)

# %%
mse_train = mse_resnet['train_mse'][1:]
mse_val = mse_resnet['val_mse'][1:]
loss_train = losses_resnet['train_loss'][1:]
loss_val = losses_resnet['val_loss'][1:]
mae_train = mae_resnet['train_mae'][1:]
mae_val = mae_resnet['val_mae'][1:]
r2_val = r2_resnet['val_r2'][1:]
r2_train = r2_resnet['train_r2'][1:]

# %%
r2_train
# Out:
# [[0.18229598466946206, 0.17201063221364066],
#  [0.30475416483418893, 0.27914706318914984],
#  [0.34045505891675154, 0.3150970714417457],
#  [0.36813143203743703, 0.33235093669226345],
#  [0.3845100893755714, 0.3437461007353707],
#  [0.3991722734516653, 0.35459611880376884],
#  [0.4085085434893466, 0.3616912522784309],
#  [0.41814577319562907, 0.36909177460090314],
#  [0.42497040123689234, 0.3743058968117501],
#  [0.43121096926040536, 0.38067521236981594],
#  [0.4360863299849722, 0.38562841823127647],
#  [0.4409019536829992, 0.38910490018672106],
#  [0.44406305806077007, 0.39321711715193],
#  [0.4476564979154469, 0.3957006967298087],
#  [0.4499267983676467, 0.3981244552295178],
#  [0.45344654790419436, 0.4007320790257688],
#  [0.45584063723933876, 0.40253023769006024],
#  [0.45847141627276033, 0.4038628812291608],
#  [0.4596987937254786, 0.4056151702889558],
#  [0.46220814969817037, 0.40813018946720214],
#  [0.46372440510446655, 0.4100579359020722],
# ...

# %%
mse_val_sbp, mse_val_dbp = extract(mse_val)
mse_train_sbp, mse_train_dbp = extract(mse_train)

mae_val_sbp, mae_val_dbp = extract(mae_val)
mae_train_sbp, mae_train_dbp = extract(mae_train)

# %%
mae_val_sbp
# Out:
# [12.704563093648638,
#  12.167962724603925,
#  12.251161045319693,
#  11.617315087100438,
#  11.367562822096689,
#  12.870066405350821,
#  11.081650107710702,
#  11.31071378225599,
#  10.933117698914664,
#  11.163510718509128,
#  10.972782774870737,
#  10.8844542345047,
#  11.114636089188712,
#  10.872031181144715,
#  10.940436027772085,
#  10.6930293365751,
#  10.80392666596004,
#  10.746039590917315,
#  10.824149544170925,
#  10.73520786367144,
#  10.716926248959133,
#  10.740648053250993,
#  10.57695402987344,
#  10.894705845178876,
#  10.631105501937867,
#  10.782651614843097,
#  10.605914354624067,
#  10.708051773888725,
#  10.500219586590358,
#  10.676739134107317,
#  10.487457702909197,
#  10.678453222084045,
#  10.464122480746678,
#  10.679016617883955,
#  10.576022779682704,
#  10.502628847748893,
#  10.426802036639621,
#  10.588642692892892,
#  10.462990523501805,
#  10.674828494235447,
#  10.401196093341282,
#  10.418911303520202,
#  10.38337071258,
#  10.553532082230705,
# ...

# %%
# Plot the losses
plt.plot(mae_val_sbp, label='Validation Loss')
plt.plot(mae_train_sbp, label='Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('ResNet MAE Loss')
plt.ylim(8, 16)
plt.legend()
plt.show()

plt.plot(mse_val_sbp, label='Validation Loss')
plt.plot(mse_train_sbp, label='Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('ResNet MSE Loss')
plt.ylim(100, 300)
plt.legend()
plt.show()

plt.plot(loss_val, label='Validation Loss')
plt.plot(loss_train, label='Training Loss')
plt.plot(mse_val_dbp, alpha=0.5, label='DBP Validation Loss')
plt.plot(mse_train_dbp, alpha=0.5, label='DBP Training Loss')
plt.plot(mse_val_sbp, alpha=0.5, label='SBP Validation Loss')
plt.plot(mse_train_sbp, alpha=0.5, label='SBP Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('ResNet Combined Loss')
plt.ylim(50, 500)
plt.legend()
plt.legend(fontsize="10")
plt.grid(True)
#plt.show()

# Save the plot with higher resolution (dpi)
plt.savefig('resnet_loss.png', dpi=600)

# %% [markdown]
# ## Misc. Figures ##

# %% [markdown]
# Figure 1, image of a nice PPG signal with processing pipeline

# %%
with open('/Users/rohansanda/Desktop/cs229_proj/data/test3_rs_testset_segments.pickle', 'rb') as file:
    segs = pickle.load(file)

# %%
plt.plot(segs[1,:])

# %%
ppg_signal = segs[1,:]

# %%
import matplotlib.pyplot as plt

# Assuming you have a vector `ppg_signal` containing the already normalized PPG signal
# Replace `ppg_signal` with your actual data

# Create a figure and axis object
fig, ax = plt.subplots(figsize=(10, 6))

# Set the font to serif and size 14
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.size'] = 14

# Plot the PPG signal
ax.plot(range(len(ppg_signal)), ppg_signal)

# # Add labels for the dicrotic notch, systolic peak, and diastolic peak
# notch_index = 100
# systolic_index = ppg_signal.argmax()
# diastolic_index = 118

# ax.annotate('Dicrotic Notch', xy=(notch_index, ppg_signal[notch_index]), xytext=(notch_index, ppg_signal[notch_index] - 0.1),
#             fontsize=10, ha='center', va='top')

# ax.annotate('Systolic Peak', xy=(systolic_index, ppg_signal[systolic_index]), xytext=(systolic_index, ppg_signal[systolic_index] + 0.01),
#             fontsize=10, ha='center', va='bottom')

# ax.annotate('Diastolic Peak', xy=(diastolic_index, ppg_signal[diastolic_index]), xytext=(diastolic_index, ppg_signal[diastolic_index] - 0.1),
#             fontsize=10, ha='center', va='top')

# points_x = [notch_index, systolic_index, diastolic_index]
# points_y = [ppg_signal[notch_index], ppg_signal[systolic_index], ppg_signal[diastolic_index]]
# ax.scatter(points_x, points_y, color='red', zorder=10)

# # Set the labels and title
ax.set_xlabel('Samples (n)', fontname='serif', fontsize=24)
ax.set_ylabel('Amplitude', fontname='serif', fontsize=24)
ax.set_title('PPG Pulse', fontname='serif', fontsize=24)

# Save the plot with higher resolution (dpi)
plt.savefig('histogram.png', dpi=600)

# Show the plot
#plt.show()

# %% [markdown]
# ## Error Analysis ##

# %% [markdown]
# #### CNN Error Analysis ####

# %%
pred_sbp = np.load('/Users/rohansanda/Desktop/cs229_proj/6_7_losses/cnn/test/predicted_sbp.npy')
pred_dbp = np.load('/Users/rohansanda/Desktop/cs229_proj/6_7_losses/cnn/test/predicted_dbp.npy')
actual_sbp = np.load('/Users/rohansanda/Desktop/cs229_proj/6_7_losses/cnn/test/actual_sbp.npy')
actual_dbp = np.load('/Users/rohansanda/Desktop/cs229_proj/6_7_losses/cnn/test/actual_dbp.npy')
segs = np.load('/Users/rohansanda/Desktop/cs229_proj/6_7_losses/cnn/test/train_segments.npy')

# %%
len(pred_sbp)
# Out:
# 71803

# %%
diffs_sbp = np.abs(pred_sbp - actual_sbp)
diffs_dbp = np.abs(pred_dbp - actual_dbp)

# %%
# Plot a histogram of the differences

# Scatter plot
plt.scatter(actual_sbp, pred_sbp, color='blue', label='Data Points')

# Fit a line
plt.plot(actual_sbp, actual_sbp, color='red', linestyle='--', label='Ideal Line')

# Set labels and title
plt.xlabel('Actual SBP')
plt.ylabel('CNN Predicted SBP')
plt.title('Actual vs Predicted SBP (CNN)')

# Set legend
plt.legend()
plt.savefig('cnn_sbp_error.png', dpi=600)

# Display the plot
plt.show()

# %%
# Plot a histogram of the differences

# Scatter plot
plt.scatter(actual_dbp, pred_dbp, color='blue', label='Data Points')

# Fit a line
plt.plot(actual_dbp, actual_dbp, color='red', linestyle='--', label='Ideal Line')

# Set labels and title
plt.xlabel('Actual DBP')
plt.ylabel('CNN Predicted DBP')
plt.title('Actual vs Predicted DBP (CNN)')

# Set legend
plt.legend()

plt.savefig('cnn_dbp_error.png', dpi=600)
# Display the plot
plt.show()

# %%
pred_sbp = np.load('/Users/rohansanda/Desktop/cs229_proj/6_7_losses/ann/test/predicted_sbp.npy')
pred_dbp = np.load('/Users/rohansanda/Desktop/cs229_proj/6_7_losses/ann/test/predicted_dbp.npy')
actual_sbp = np.load('/Users/rohansanda/Desktop/cs229_proj/6_7_losses/ann/test/actual_sbp.npy')
actual_dbp = np.load('/Users/rohansanda/Desktop/cs229_proj/6_7_losses/ann/test/actual_dbp.npy')
segs = np.load('/Users/rohansanda/Desktop/cs229_proj/6_7_losses/ann/test/train_segments.npy')

# %%
# Plot a histogram of the differences

# Scatter plot
plt.scatter(actual_sbp, pred_sbp, color='blue', label='Data Points')

# Fit a line
plt.plot(actual_sbp, actual_sbp, color='red', linestyle='--', label='Ideal Line')

# Set labels and title
plt.xlabel('Actual SBP')
plt.ylabel('ANN Predicted SBP')
plt.title('Actual vs Predicted SBP (ANN)')

# Set legend
plt.legend()
plt.savefig('ann_sbp_error.png', dpi=600)

# Display the plot
plt.show()

# %%
# Plot a histogram of the differences

# Scatter plot
plt.scatter(actual_dbp, pred_dbp, color='blue', label='Data Points')

# Fit a line
plt.plot(actual_dbp, actual_dbp, color='red', linestyle='--', label='Ideal Line')

# Set labels and title
plt.xlabel('Actual DBP')
plt.ylabel('ANN Predicted DBP')
plt.title('Actual vs Predicted DBP (ANN)')

# Set legend
plt.legend()
plt.savefig('ann_dbp_error.png', dpi=600)

# Display the plot
plt.show()
